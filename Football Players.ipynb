# %%
import  pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fifa =  pd.read_csv("players_20.csv")

# %%
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
for col in fifa.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
fifa.shape
# Out:
# (18278, 104)

# %%
fifa['nationality'].value_counts()
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Liberia                   1
# São Tomé & Príncipe       1
# Puerto Rico               1
# Bahrain                   1
# Indonesia                 1
# Name: nationality, Length: 162, dtype: int64

# %%
fifa['nationality'].value_counts()[0:5]
# Out:
# England      1667
# Germany      1216
# Spain        1035
# France        984
# Argentina     886
# Name: nationality, dtype: int64

# %%
fifa['nationality'].value_counts().max()
# Out:
# 1667

# %%
fifa['nationality'].value_counts().keys()[0:5]
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina'], dtype='object')

# %%
plt.figure(figsize=(8,5))
plt.bar(list(fifa['nationality'].value_counts()[0:5].keys()) , list(fifa['nationality'].value_counts()[0:5]) , color=['red' , 'green' , 'blue'])
plt.show()

# %%
player_salary = fifa[['short_name' , 'wage_eur']]

# %%
hig_salary  =  player_salary.sort_values('wage_eur' , ascending=False).head()

# %%
plt.figure(figsize=(8,5))
plt.bar(list(hig_salary['short_name']) , list(hig_salary['wage_eur']))
plt.show()

# %%
# German Players
ger_filt = fifa['nationality'] == "Germany"
# fifa.loc[ger_filt][['short_name' , 'wage_eur' , 'age']]
Germany = fifa[ger_filt]

# %%
Germany.sort_values(['height_cm'],ascending=False)
# Out:
#        sofifa_id                                         player_url  \
# 8016      236831  https://sofifa.com/player/236831/aaron-seydel/...
# 1217      200212  https://sofifa.com/player/200212/michael-esser...
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...
# 11859     167437  https://sofifa.com/player/167437/dominik-stroh...
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
# ...          ...                                                ...
# 17889     239129  https://sofifa.com/player/239129/jakob-gesien/...
# 6364      189209  https://sofifa.com/player/189209/sascha-bigalk...
# 15960     247284  https://sofifa.com/player/247284/patrick-finge...
# 11380     250936  https://sofifa.com/player/250936/seref-ozcan/2...
# 11612     248879  https://sofifa.com/player/248879/kevin-holzwei...
#
#            short_name            long_name  age         dob  height_cm  \
# 8016        A. Seydel         Aaron Seydel   23  1996-02-07        199
# ...

# %%
Germany.sort_values(['weight_kg'],ascending=False)
# Out:
#        sofifa_id                                         player_url  \
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...
# 518       179783  https://sofifa.com/player/179783/ralf-fahrmann...
# 1217      200212  https://sofifa.com/player/200212/michael-esser...
# 77        212190  https://sofifa.com/player/212190/niklas-sule/2...
# ...          ...                                                ...
# 17276     248583  https://sofifa.com/player/248583/sinisa-spreca...
# 11612     248879  https://sofifa.com/player/248879/kevin-holzwei...
# 13387     252559  https://sofifa.com/player/252559/volkan-egri/2...
# 17889     239129  https://sofifa.com/player/239129/jakob-gesien/...
# 17879     244094  https://sofifa.com/player/244094/leonard-langh...
#
#            short_name           long_name  age         dob  height_cm  \
# 13576    L. Watkowiak     Lukas Watkowiak   23  1996-03-06        197
# ...

# %%
Germany.sort_values(['wage_eur'],ascending=False)
# Out:
#        sofifa_id                                         player_url  \
# 36        182521  https://sofifa.com/player/182521/toni-kroos/20...
# 6         192448  https://sofifa.com/player/192448/marc-andre-te...
# 55        222492  https://sofifa.com/player/222492/leroy-sane/20...
# 146       186942  https://sofifa.com/player/186942/ilkay-gundoga...
# 70        189596  https://sofifa.com/player/189596/thomas-muller...
# ...          ...                                                ...
# 13488     223904  https://sofifa.com/player/223904/joel-gerezgih...
# 13463     244097  https://sofifa.com/player/244097/tarsis-bonga/...
# 13458     238792  https://sofifa.com/player/238792/leon-jensen/2...
# 13373     245288  https://sofifa.com/player/245288/lukas-gottwal...
# 18197     244172  https://sofifa.com/player/244172/matthis-harsm...
#
#           short_name                      long_name  age         dob  \
# 36          T. Kroos                     Toni Kroos   29  1990-01-04
# ...

# %%
Germany[['short_name','wage_eur']].sort_values(['wage_eur'],ascending=False)
# Out:
#           short_name  wage_eur
# 36          T. Kroos    330000
# 6      M. ter Stegen    250000
# 55           L. Sané    195000
# 146      I. Gündoğan    180000
# 70         T. Müller    170000
# ...              ...       ...
# 13488  J. Gerezgiher      1000
# 13463       T. Bonga      1000
# 13458      L. Jensen      1000
# 13373    L. Gottwalt      1000
# 18197     M. Harsman      1000
#
# [1216 rows x 2 columns]

# %%
#  Shooting

# %%
player_shooting = fifa[['short_name' , 'shooting']]

# %%
player_shooting.head()
# Out:
#           short_name  shooting
# 0           L. Messi      92.0
# 1  Cristiano Ronaldo      93.0
# 2          Neymar Jr      85.0
# 3           J. Oblak       NaN
# 4          E. Hazard      83.0

# %%
# Defending
player_defending = fifa[['short_name' , 'defending' , 'nationality' , 'club']]

# %%
player_defending.sort_values('defending' , ascending=False)
# Out:
#                short_name  defending          nationality               club
# 16           G. Chiellini       90.0                Italy           Juventus
# 7             V. van Dijk       90.0          Netherlands          Liverpool
# 11           K. Koulibaly       89.0              Senegal             Napoli
# 35               D. Godín       89.0              Uruguay              Inter
# 49             M. Hummels       89.0              Germany  Borussia Dortmund
# ...                   ...        ...                  ...                ...
# 18231         P. Królczyk        NaN               Poland      Piast Gliwice
# 18239          V. Storsve        NaN               Norway      Lillestrøm SK
# 18251  G. Sykes-Kenworthy        NaN              England      Bradford City
# 18259          H. Sveijer        NaN               Sweden          IK Sirius
# 18272           P. Martin        NaN  Republic of Ireland       Waterford FC
#
# [18278 rows x 4 columns]

# %%
club_filt  = fifa['club']  ==  'Real Madrid'

# %%
real_madrid  =  fifa[club_filt]

# %%
real_madrid.sort_values(by=['wage_eur'] , ascending=False)
# Out:
#        sofifa_id                                         player_url  \
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# 8         177003  https://sofifa.com/player/177003/luka-modric/2...
# 36        182521  https://sofifa.com/player/182521/toni-kroos/20...
# 18        155862  https://sofifa.com/player/155862/sergio-ramos-...
# 46        165153  https://sofifa.com/player/165153/karim-benzema...
# 100       173731  https://sofifa.com/player/173731/gareth-bale/2...
# 62        197781  https://sofifa.com/player/197781/francisco-rom...
# 42        200145  https://sofifa.com/player/200145/carlos-henriq...
# 28        192119  https://sofifa.com/player/192119/thibaut-court...
# 106       198710  https://sofifa.com/player/198710/james-rodrigu...
# 76        201535  https://sofifa.com/player/201535/raphael-varan...
# 94        204963  https://sofifa.com/player/204963/daniel-carvaj...
# 101       176676  https://sofifa.com/player/176676/marcelo-vieir...
# ...

# %%
real_madrid.sort_values(by=['shooting'] , ascending=False)
# Out:
#        sofifa_id                                         player_url  \
# 100       173731  https://sofifa.com/player/173731/gareth-bale/2...
# 106       198710  https://sofifa.com/player/198710/james-rodrigu...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# 46        165153  https://sofifa.com/player/165153/karim-benzema...
# 161       232432  https://sofifa.com/player/232432/luka-jovic/20...
# 36        182521  https://sofifa.com/player/182521/toni-kroos/20...
# 178       220834  https://sofifa.com/player/220834/marco-asensio...
# 636       221639  https://sofifa.com/player/221639/mariano-diaz-...
# 62        197781  https://sofifa.com/player/197781/francisco-rom...
# 8         177003  https://sofifa.com/player/177003/luka-modric/2...
# 101       176676  https://sofifa.com/player/176676/marcelo-vieir...
# 403       208618  https://sofifa.com/player/208618/lucas-vazquez...
# 42        200145  https://sofifa.com/player/200145/carlos-henriq...
# ...

# %%
real_madrid.sort_values(by=['defending'] , ascending=False)
# Out:
#        sofifa_id                                         player_url  \
# 18        155862  https://sofifa.com/player/155862/sergio-ramos-...
# 42        200145  https://sofifa.com/player/200145/carlos-henriq...
# 76        201535  https://sofifa.com/player/201535/raphael-varan...
# 94        204963  https://sofifa.com/player/204963/daniel-carvaj...
# 332       240130  https://sofifa.com/player/240130/eder-gabriel-...
# 277       200724  https://sofifa.com/player/200724/jose-ignacio-...
# 101       176676  https://sofifa.com/player/176676/marcelo-vieir...
# 437       234035  https://sofifa.com/player/234035/alvaro-odrioz...
# 424       228618  https://sofifa.com/player/228618/ferland-mendy...
# 8         177003  https://sofifa.com/player/177003/luka-modric/2...
# 2286      209749  https://sofifa.com/player/209749/lucas-silva-b...
# 36        182521  https://sofifa.com/player/182521/toni-kroos/20...
# 5676      244523  https://sofifa.com/player/244523/javier-hernan...
# ...

# %%
real_madrid['nationality'].value_counts()
# Out:
# Spain                 13
# Brazil                 6
# France                 3
# Belgium                2
# Croatia                1
# Germany                1
# Costa Rica             1
# Wales                  1
# Colombia               1
# Serbia                 1
# Dominican Republic     1
# Uruguay                1
# Japan                  1
# Name: nationality, dtype: int64
